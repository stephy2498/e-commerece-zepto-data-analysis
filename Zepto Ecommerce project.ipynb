# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\USER\Downloads\zepto.csv')

# %%
df.head(5)
# Out:
#               category              name   mrp  discount percent  \
# 0  Fruits & Vegetables             Onion  2500                16
# 1  Fruits & Vegetables     Tomato Hybrid  4200                16
# 2  Fruits & Vegetables    Tender Coconut  5100                15
# 3  Fruits & Vegetables  Coriander Leaves  2000                15
# 4  Fruits & Vegetables    Ladies Finger   1400                14
#
#    available quantity  discounted selling price  weight In gms  out of stock  \
# 0                   3                      2100           1000         False
# 1                   3                      3500           1000         False
# 2                   3                      4300             58         False
# 3                   3                      1700            100         False
# 4                   3                      1200            250         False
#
#    quantity
# 0         1
# 1         1
# 2         1
# 3       100
# 4       250

# %%
df.describe()
# Out:
#                  mrp  discount percent  available quantity  \
# count    3732.000000       3732.000000         3732.000000
# mean    15680.117899          7.617095            4.008574
# std     16088.807618          9.211733            2.203511
# min         0.000000          0.000000            0.000000
# 25%      6000.000000          0.000000            2.000000
# 50%     11000.000000          6.000000            5.000000
# 75%     20000.000000         10.000000            6.000000
# max    260000.000000         51.000000            6.000000
#
#        discounted selling price  weight In gms     quantity
# count               3732.000000    3732.000000  3732.000000
# mean               14192.834941     387.843783   213.270900
# std                13850.726265     678.096509   194.730976
# min                    0.000000       0.000000     0.000000
# 25%                 5500.000000     100.000000    50.000000
# 50%                10400.000000     225.000000   186.000000
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                  category                                               name  \
# 0     Fruits & Vegetables                                              Onion
# 1     Fruits & Vegetables                                      Tomato Hybrid
# 2     Fruits & Vegetables                                     Tender Coconut
# 3     Fruits & Vegetables                                   Coriander Leaves
# 4     Fruits & Vegetables                                     Ladies Finger
# ...                   ...                                                ...
# 3727     Health & Hygiene  Stayfree Secure Dry Cover Extra Large Sanitary...
# 3728     Health & Hygiene  Dabur Honitus Herbal Cough Remedy Ayurvedic Syrup
# 3729     Health & Hygiene       Whisper Bindazzz Night Sanitary Pads XL Plus
# 3730     Health & Hygiene                             Fine Life Cotton Balls
# 3731     Health & Hygiene                           Dettol Antiseptic Liquid
#
# ...

# %%
df.columns
# Out:
# Index(['category', 'name', 'mrp', 'discount percent', 'available quantity',
#        'discounted selling price', 'weight In gms', 'out of stock',
#        'quantity'],
#       dtype='str')

# %%
df.shape
# Out:
# (3732, 9)

# %%
df.isnull().sum()
# Out:
# category                    0
# name                        0
# mrp                         0
# discount percent            0
# available quantity          0
# discounted selling price    0
# weight In gms               0
# out of stock                0
# quantity                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates()
# Out:
#                  category                                               name  \
# 0     Fruits & Vegetables                                              Onion
# 1     Fruits & Vegetables                                      Tomato Hybrid
# 2     Fruits & Vegetables                                     Tender Coconut
# 3     Fruits & Vegetables                                   Coriander Leaves
# 4     Fruits & Vegetables                                     Ladies Finger
# ...                   ...                                                ...
# 3727     Health & Hygiene  Stayfree Secure Dry Cover Extra Large Sanitary...
# 3728     Health & Hygiene  Dabur Honitus Herbal Cough Remedy Ayurvedic Syrup
# 3729     Health & Hygiene       Whisper Bindazzz Night Sanitary Pads XL Plus
# 3730     Health & Hygiene                             Fine Life Cotton Balls
# 3731     Health & Hygiene                           Dettol Antiseptic Liquid
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.info
# Out:
# <bound method DataFrame.info of                  category                                               name  \
# 0     Fruits & Vegetables                                              Onion
# 1     Fruits & Vegetables                                      Tomato Hybrid
# 2     Fruits & Vegetables                                     Tender Coconut
# 3     Fruits & Vegetables                                   Coriander Leaves
# 4     Fruits & Vegetables                                     Ladies Finger
# ...                   ...                                                ...
# 3727     Health & Hygiene  Stayfree Secure Dry Cover Extra Large Sanitary...
# 3728     Health & Hygiene  Dabur Honitus Herbal Cough Remedy Ayurvedic Syrup
# 3729     Health & Hygiene       Whisper Bindazzz Night Sanitary Pads XL Plus
# 3730     Health & Hygiene                             Fine Life Cotton Balls
# 3731     Health & Hygiene                           Dettol Antiseptic Liquid
#
# ...

# %%
df['category'].unique()
# Out:
# <StringArray>
# [  'Fruits & Vegetables',    'Cooking Essentials',              'Munchies',
#  'Dairy, Bread & Batter',             'Beverages',         'Packaged Food',
#   'Ice Cream & Desserts',  'Chocolates & Candies',    'Meats, Fish & Eggs',
#               'Biscuits',         'Personal Care',           'Paan Corner',
#        'Home & Cleaning',      'Health & Hygiene']
# Length: 14, dtype: str

# %%
df['name'].unique()
# Out:
# <StringArray>
# [                                            'Onion',
#                                      'Tomato Hybrid',
#                                     'Tender Coconut',
#                                   'Coriander Leaves',
#                                     'Ladies Finger ',
#                                             'Potato',
#                                              'Lemon',
#                                        'Watermelon ',
#                                    'Capsicum Green ',
#                                      'Chilli Green ',
#  ...
#                               'Dabur - Chyawanprash',
#                                      'Vicks BabyRub',
#                        'Organic India Brahmi Bottle',
#                    'Horlicks Protein Plus Chocolate',
#          'Dabur Nature Care Isabgol - Double Action',
#                    'Kapiva Wild Tulsi Giloy Juice |',
#                                   'Dabur Amla Juice',
# ...

# %%
df['mrp'].min()
df['mrp'].max()

df['discount percent'].min()
df['discount percent'].max()

df['available quantity'].min()
# Out:
# np.int64(0)

# %%
category_df=df.groupby(by=['category','available quantity'])
print(category_df.groups)
# Out:
# {('Beverages', 0): RangeIndex(start=1351, stop=1379, step=1), ('Beverages', 1): Index([1272, 1283, 1293, 1294, 1296, 1307, 1332, 1344], dtype='int64'), ('Beverages', 2): RangeIndex(start=1288, stop=1332, step=22), ('Beverages', 3): Index([1269, 1281, 1295], dtype='int64'), ('Beverages', 4): Index([1250, 1252, 1254, 1257, 1258, 1261, 1263, 1264, 1266, 1273, 1276, 1280,
#        1289, 1290, 1297, 1303, 1304, 1305, 1311, 1313, 1315, 1317, 1322, 1323,
#        1327, 1329, 1336, 1345, 1349],
#       dtype='int64'), ('Beverages', 5): Index([1286, 1287, 1300, 1314, 1330, 1335], dtype='int64'), ('Beverages', 6): Index([1251, 1253, 1255, 1256, 1259, 1260, 1262, 1265, 1267, 1268, 1270, 1271,
#        1274, 1275, 1277, 1278, 1279, 1282, 1284, 1285, 1291, 1292, 1298, 1299,
#        1301, 1302, 1306, 1308, 1309, 1312, 1316, 1318, 1319, 1320, 1321, 1324,
#        1325, 1326, 1328, 1331, 1333, 1334, 1337, 1338, 1339, 1340, 1341, 1342,
#        1343, 1346, 1347, 1348, 1350],
# ...

# %%
df.columns
# Out:
# Index(['category', 'name', 'mrp', 'discount percent', 'available quantity',
#        'discounted selling price', 'weight In gms', 'out of stock',
#        'quantity'],
#       dtype='str')

# %%
df['mrp'].min()
# Out:
# np.int64(0)

# %%
df['mrp'].max()
# Out:
# np.int64(260000)

# %%
df['discounted selling price'].min()
# Out:
# np.int64(0)

# %%
df['discounted selling price'].max()
# Out:
# np.int64(139900)

# %%
df['available quantity'].min()
# Out:
# np.int64(0)

# %%
df['available quantity'].max()
# Out:
# np.int64(6)

# %%
df[df['mrp']<=0]
# Out:
#              category                                        name  mrp  \
# 3606  Home & Cleaning  Cherry Blossom Liquid Shoe Polish Neutral     0
#
#       discount percent  available quantity  discounted selling price  \
# 3606                 0                   1                         0
#
#       weight In gms  out of stock  quantity
# 3606             75         False        75

# %%
df[df['discounted selling price']<=0]
# Out:
#              category                                        name  mrp  \
# 3606  Home & Cleaning  Cherry Blossom Liquid Shoe Polish Neutral     0
#
#       discount percent  available quantity  discounted selling price  \
# 3606                 0                   1                         0
#
#       weight In gms  out of stock  quantity
# 3606             75         False        75

# %%
df['discount amount']=df['mrp']-df['discounted selling price']
print('discount amount')
df.head (5)
# Out:
# discount amount
#               category              name   mrp  discount percent  \
# 0  Fruits & Vegetables             Onion  2500                16
# 1  Fruits & Vegetables     Tomato Hybrid  4200                16
# 2  Fruits & Vegetables    Tender Coconut  5100                15
# 3  Fruits & Vegetables  Coriander Leaves  2000                15
# 4  Fruits & Vegetables    Ladies Finger   1400                14
#
#    available quantity  discounted selling price  weight In gms  out of stock  \
# 0                   3                      2100           1000         False
# 1                   3                      3500           1000         False
# 2                   3                      4300             58         False
# 3                   3                      1700            100         False
# 4                   3                      1200            250         False
#
#    quantity  discount amount
# 0         1              400
# 1         1              700
# ...

# %%
df['revenue']=df['discounted selling price']*df['quantity']
df.head(5)
# Out:
#               category              name   mrp  discount percent  \
# 0  Fruits & Vegetables             Onion  2500                16
# 1  Fruits & Vegetables     Tomato Hybrid  4200                16
# 2  Fruits & Vegetables    Tender Coconut  5100                15
# 3  Fruits & Vegetables  Coriander Leaves  2000                15
# 4  Fruits & Vegetables    Ladies Finger   1400                14
#
#    available quantity  discounted selling price  weight In gms  out of stock  \
# 0                   3                      2100           1000         False
# 1                   3                      3500           1000         False
# 2                   3                      4300             58         False
# 3                   3                      1700            100         False
# 4                   3                      1200            250         False
#
#    quantity  discount amount  revenue
# 0         1              400     2100
# ...

# %%
df['category'].value_counts()
# Out:
# category
# Cooking Essentials       514
# Munchies                 514
# Packaged Food            388
# Ice Cream & Desserts     388
# Chocolates & Candies     388
# Personal Care            344
# Paan Corner              344
# Home & Cleaning          194
# Biscuits                 147
# Dairy, Bread & Batter    129
# Beverages                129
# Health & Hygiene          97
# Fruits & Vegetables       93
# Meats, Fish & Eggs        63
# Name: count, dtype: int64

# %%
df.groupby('category')['mrp'].mean().sort_values(ascending=False)
# Out:
# category
# Paan Corner              20711.918605
# Personal Care            20711.918605
# Meats, Fish & Eggs       18728.571429
# Health & Hygiene         15917.525773
# Cooking Essentials       15653.501946
# Munchies                 15653.501946
# Chocolates & Candies     15572.680412
# Ice Cream & Desserts     15572.680412
# Packaged Food            15572.680412
# Home & Cleaning          15215.463918
# Beverages                11870.542636
# Dairy, Bread & Batter    11870.542636
# Biscuits                  5948.979592
# Fruits & Vegetables       4701.075269
# Name: mrp, dtype: float64

# %%
df.groupby('category')['discount percent'].mean().sort_values(ascending=False)
# Out:
# category
# Fruits & Vegetables      15.462366
# Meats, Fish & Eggs       11.031746
# Chocolates & Candies      8.324742
# Ice Cream & Desserts      8.324742
# Packaged Food             8.324742
# Biscuits                  8.244898
# Health & Hygiene          8.051546
# Cooking Essentials        7.163424
# Munchies                  7.163424
# Beverages                 7.155039
# Dairy, Bread & Batter     7.155039
# Paan Corner               6.250000
# Personal Care             6.250000
# Home & Cleaning           5.675258
# Name: discount percent, dtype: float64

# %%
df[['name','category','mrp']].sort_values(
    by='mrp',ascending=False).head(10)
# Out:
#                                          name            category     mrp
# 1031     Borges Extra Light Olive Oil Bottle             Munchies  260000
# 517      Borges Extra Light Olive Oil Bottle   Cooking Essentials  260000
# 3016                    Pampers Pants - Large       Personal Care  154900
# 3360                    Pampers Pants - Large         Paan Corner  154900
# 877   Praakritik Natural Desi Gir Cow A2 Ghee            Munchies  145000
# 363   Praakritik Natural Desi Gir Cow A2 Ghee  Cooking Essentials  145000
# 121         Dhara Kachi Ghani Mustard Oil Jar  Cooking Essentials  125000
# 635         Dhara Kachi Ghani Mustard Oil Jar            Munchies  125000
# 144                        Saffola Gold (Jar)  Cooking Essentials  124000
# 658                        Saffola Gold (Jar)            Munchies  124000

# %%
count_of_out_of_stock=df['out of stock'].value_counts()
print(count_of_out_of_stock)
# Out:
# out of stock
# False    3279
# True      453
# Name: count, dtype: int64

# %%
df.groupby('category')['out of stock'].sum().sort_values(ascending=False)
# Out:
# category
# Cooking Essentials       64
# Munchies                 64
# Chocolates & Candies     45
# Ice Cream & Desserts     45
# Packaged Food            45
# Biscuits                 42
# Beverages                28
# Dairy, Bread & Batter    28
# Paan Corner              21
# Personal Care            21
# Home & Cleaning          19
# Health & Hygiene         13
# Meats, Fish & Eggs       12
# Fruits & Vegetables       6
# Name: out of stock, dtype: int64

# %%
df.groupby('category')['available quantity'].sum().sort_values(ascending=False)
# Out:
# category
# Cooking Essentials       2186
# Munchies                 2186
# Chocolates & Candies     1521
# Ice Cream & Desserts     1521
# Packaged Food            1521
# Paan Corner              1458
# Personal Care            1458
# Home & Cleaning           839
# Beverages                 485
# Dairy, Bread & Batter     485
# Biscuits                  448
# Health & Hygiene          425
# Fruits & Vegetables       275
# Meats, Fish & Eggs        152
# Name: available quantity, dtype: int64

# %%
df[['name,'category','mrp','discount percent',
    'discounted selling price']].sort_values(
    by='discount percent',
    ascending=False
    ).head(10)
# Out:
#   Cell In[94], line 1
#     df[['name,'category','mrp','discount percent',
#                                                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df[['name','category','mrp','discount percent',
    'discounted selling price']].sort_values(
        by='discount percent',
        ascending=False
).head(10)
# Out:
#                                              name               category  \
# 2608                 Dukes Waffy Chocolate Wafers               Biscuits
# 2615                    Dukes Waffy Orange Wafers               Biscuits
# 2619                Dukes Waffy Strawberry Wafers               Biscuits
# 2219      Chef's Basket Durum Wheat Fusilli Pasta   Chocolates & Candies
# 1431        Chef's Basket Durum Wheat Elbow Pasta          Packaged Food
# 2586  Ceres Foods Laal Maas Instant Liquid Masala     Meats, Fish & Eggs
# 1200                           RRO Burrata Cheese  Dairy, Bread & Batter
# 1197                  RRO Mozzarella Pizza Cheese  Dairy, Bread & Batter
# 1195                            RRO Fresh Ricotta  Dairy, Bread & Batter
# 1191                     RRO Cheddar Block Cheese  Dairy, Bread & Batter
#
#         mrp  discount percent  discounted selling price
# 2608   4500                51                      2200
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['category'].value_counts().head(10).plot(kind='bar')
plt.title('top product category')
plt.xlabel('category')
plt.ylabel('number of product')
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df['discount percent'],bins=20)
plt.title('discount Distribution')
plt.show()

# %%
plt.scatter(
    df['mrp'],
    df['discounted selling price']
)
plt.xlabel('mrp')
plt.ylabel('selling price')
plt.title('Mrp vs discounted selling Price')
plt.show()

# %%
plt.plot(df['category'],
         df['mrp'],
         
)
plt.xlabel('no of categpry')
plt.ylabel(' mrp')
plt.show()

# %%
plt.bar('category','mrp')
plt.show()
